# %% [markdown]
# # Web Scrapint con BeautifulSoup

# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.1.1; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 142 kB 2.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.1; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Enviar petición HTTP para extraer código fuente de la Página Web

# %%
page = requests.get('http://books.toscrape.com/')
print(page)
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
travel_page = requests.get('http://books.toscrape.com/catalogue/category/books/travel_2/index.html')

# %% [markdown]
# ### Analizar codigo fuente

# %%
# Nos extrae la 1er etiqueta <a...
titulo_item = soup.find('a')
print(titulo_item)
# Out:
# <a href="index.html">Books to Scrape</a>

# %%
# Nos extrae todas las etiquetas <a...
titulo_items = soup.find_all('a')
print(titulo_items)
# Out:
# [<a href="index.html">Books to Scrape</a>, <a href="index.html">Home</a>, <a href="catalogue/category/books_1/index.html">
#
#                                 Books
#
#                         </a>, <a href="catalogue/category/books/travel_2/index.html">
#
#                                 Travel
#
#                         </a>, <a href="catalogue/category/books/mystery_3/index.html">
#
#                                 Mystery
#
#                         </a>, <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                 Historical Fiction
#
#                         </a>, <a href="catalogue/category/books/sequential-art_5/index.html">
#
#                                 Sequential Art
#
#                         </a>, <a href="catalogue/category/books/classics_6/index.html">
#
#                                 Classics
#
#                         </a>, <a href="catalogue/category/books/philosophy_7/index.html">
#
# ...

# %%
# Podemos agregar filtros, segun sus propiedades, identificadores, etc.
titulo_items = soup.find_all('h3')
for items in titulo_items:
    # accedemos a su etiqueta a
    titulo = items.a
    print(titulo.attrs)
# Out:
# {'href': 'catalogue/a-light-in-the-attic_1000/index.html', 'title': 'A Light in the Attic'}
# {'href': 'catalogue/tipping-the-velvet_999/index.html', 'title': 'Tipping the Velvet'}
# {'href': 'catalogue/soumission_998/index.html', 'title': 'Soumission'}
# {'href': 'catalogue/sharp-objects_997/index.html', 'title': 'Sharp Objects'}
# {'href': 'catalogue/sapiens-a-brief-history-of-humankind_996/index.html', 'title': 'Sapiens: A Brief History of Humankind'}
# {'href': 'catalogue/the-requiem-red_995/index.html', 'title': 'The Requiem Red'}
# {'href': 'catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html', 'title': 'The Dirty Little Secrets of Getting Your Dream Job'}
# {'href': 'catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html', 'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull'}
# ...

# %%
# Podemos agregar filtros, segun sus propiedades, identificadores, etc.
titulos = []
titulo_items = soup.find_all('h3')
for items in titulo_items:
    # accedemos a su etiqueta a
    titulo = items.a
    print(titulo['title'])
    titulos.append(titulo['title'])
# Out:
# A Light in the Attic
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History of Humankind
# The Requiem Red
# The Dirty Little Secrets of Getting Your Dream Job
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# The Black Maria
# Starving Hearts (Triangular Trade Trilogy, #1)
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# Rip it Up and Start Again
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# Olio
# Mesaerion: The Best Science Fiction Stories 1800-1849
# Libertarianism for Beginners
# It's Only the Himalayas

# %%
print(titulos)
# Out:
# ['A Light in the Attic', 'Tipping the Velvet', 'Soumission', 'Sharp Objects', 'Sapiens: A Brief History of Humankind', 'The Requiem Red', 'The Dirty Little Secrets of Getting Your Dream Job', 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'The Black Maria', 'Starving Hearts (Triangular Trade Trilogy, #1)', "Shakespeare's Sonnets", 'Set Me Free', "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'Rip it Up and Start Again', 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'Olio', 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'Libertarianism for Beginners', "It's Only the Himalayas"]

# %%
# Para sacar el precio es diferente, porque esta en forma de texto
precios = []
precio_items = soup.find_all('p',class_="price_color")
print(precio_items)
# Out:
# [<p class="price_color">Â£51.77</p>, <p class="price_color">Â£53.74</p>, <p class="price_color">Â£50.10</p>, <p class="price_color">Â£47.82</p>, <p class="price_color">Â£54.23</p>, <p class="price_color">Â£22.65</p>, <p class="price_color">Â£33.34</p>, <p class="price_color">Â£17.93</p>, <p class="price_color">Â£22.60</p>, <p class="price_color">Â£52.15</p>, <p class="price_color">Â£13.99</p>, <p class="price_color">Â£20.66</p>, <p class="price_color">Â£17.46</p>, <p class="price_color">Â£52.29</p>, <p class="price_color">Â£35.02</p>, <p class="price_color">Â£57.25</p>, <p class="price_color">Â£23.88</p>, <p class="price_color">Â£37.59</p>, <p class="price_color">Â£51.33</p>, <p class="price_color">Â£45.17</p>]

# %%
for item in precio_items:
    # accedemos a su etiqueta a
    #cprecio = item.text.split('Â')
    cprecio = item.text
    print(cprecio)
    precios.append(cprecio)
# Out:
# Â£51.77
# Â£53.74
# Â£50.10
# Â£47.82
# Â£54.23
# Â£22.65
# Â£33.34
# Â£17.93
# Â£22.60
# Â£52.15
# Â£13.99
# Â£20.66
# Â£17.46
# Â£52.29
# Â£35.02
# Â£57.25
# Â£23.88
# Â£37.59
# Â£51.33
# Â£45.17

# %%
print(precios)
# Out:
# ['Â£51.77', 'Â£53.74', 'Â£50.10', 'Â£47.82', 'Â£54.23', 'Â£22.65', 'Â£33.34', 'Â£17.93', 'Â£22.60', 'Â£52.15', 'Â£13.99', 'Â£20.66', 'Â£17.46', 'Â£52.29', 'Â£35.02', 'Â£57.25', 'Â£23.88', 'Â£37.59', 'Â£51.33', 'Â£45.17']

# %%
existencia = []

existencia_items = soup.find_all('p', class_='instock availability')

for item in existencia_items:
    existencia_item = item.text.strip()
    existencia.append(existencia_item)
    print(existencia_item)
# Out:
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock

# %%
print(existencia)
# Out:
# ['In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock', 'In stock']

# %%
raitings = []
raiting_item = soup.find_all('p', class_='star-rating')
print(raiting_item)
# Out:
# [<p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# ...

# %%
for item in raiting_item:
    raiting = item['class'][1]
    print(raiting)
    raitings.append(raiting)
# Out:
# Three
# One
# One
# Four
# Five
# One
# Four
# Three
# Four
# One
# Two
# Four
# Five
# Five
# Five
# Three
# One
# One
# Two
# Two

# %%
print(raitings)
# Out:
# ['Three', 'One', 'One', 'Four', 'Five', 'One', 'Four', 'Three', 'Four', 'One', 'Two', 'Four', 'Five', 'Five', 'Five', 'Three', 'One', 'One', 'Two', 'Two']

# %%
# como guardar todos estos arreglos en un dataFrame
import pandas as pd
data = {
    'Titulo': titulos,
    'Precio': precios,
    'Raiting': raitings,
    'En existencia': existencia
}
df = pd.DataFrame(data)
print(df)
# Out:
#                                                Titulo   Precio Raiting  \
# 0                                A Light in the Attic  Â£51.77   Three
# 1                                  Tipping the Velvet  Â£53.74     One
# 2                                          Soumission  Â£50.10     One
# 3                                       Sharp Objects  Â£47.82    Four
# 4               Sapiens: A Brief History of Humankind  Â£54.23    Five
# 5                                     The Requiem Red  Â£22.65     One
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34    Four
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93   Three
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60    Four
# 9                                     The Black Maria  Â£52.15     One
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99     Two
# 11                              Shakespeare's Sonnets  Â£20.66    Four
# ...

# %% [markdown]
# #### Ejercicio

# %%
product_page = requests.get('https://cyberpuerta.mx/Promociones/')
soup = BeautifulSoup(page.text, 'html.parser')
print(soup)
# No supe porque se regreso a la página del martes
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
page = requests.get('http://books.toscrape.com/')
print(page)
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
images_items = soup.find_all('img', class_="thumbnail")
images = []
for item in images_items:
    image = item['src']
    # print(image)
   # Como son direcciones relativas, agregamos el inicio del link de la página 
    images.append('http://books.toscrape.com/'+image)

print(images)
# Out:
# ['http://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg', 'http://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg', 'http://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg', 'http://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg', 'http://books.toscrape.com/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg', 'http://books.toscrape.com/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg', 'http://books.toscrape.com/media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg', 'http://books.toscrape.com/media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg', 'http://books.toscrape.com/media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg', 'http://books.toscrape.com/media/cache/58/46/5846057e28022268153beff6d352b06c.jpg', 'http://books.toscrape.com/media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg', 'http://books.toscrape.com/media/cache/10/48/1048f63d3b5061cd2f424d20b3f9
# ...

# %% [markdown]
# ### Paginación

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('http://books.toscrape.com/')
print(page)
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
def obtener_contenido_pagina(url):
    response = requests.get(url)
    return response.content

# %%
def analizar_contenido_html(html):
    return BeautifulSoup(html,'html.parser')

# %%
data = []
def procesar_pagina(soup):
    titulos = []
    links = []
    ratings = []
    existencias = []

    titulo_items = soup.find_all('h3')

    for items in titulo_items:
        titulo = items.a
        titulos.append(titulo['title'])
        links.append(titulo['href'])

    rating_items = soup.find_all('p', class_="star-rating")

    for item in rating_items:
        rating = item['class'][1]
        ratings.append(rating)

    existencia_items = soup.find_all('p', class_='instock availability')

    for item in existencia_items:
        existencia = item.text.strip()
        existencias.append(existencia)

    for i in range(len(titulos)):
        data.append({
            "Título": titulos[i],
            "Rating": ratings[i],
            "Link": links[i],
            "Existencia": existencias[i]
        })

# %%
def manejar_paginacion(url_base, num_paginas):
    for i in range(1, num_paginas+1):
        url = url_base + '/page-' + str(i)+'.html'
        contenido_pagina = obtener_contenido_pagina(url)
        soup = analizar_contenido_html(contenido_pagina)
        procesar_pagina(soup)

# %%
url_base = "http://books.toscrape.com/catalogue/"
num_paginas = 50 # remplazar por el total de paginas

manejar_paginacion(url_base, num_paginas)

# %%
data
# Out:
# [{'Título': 'A Light in the Attic',
#   'Rating': 'Three',
#   'Link': 'a-light-in-the-attic_1000/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'Tipping the Velvet',
#   'Rating': 'One',
#   'Link': 'tipping-the-velvet_999/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'Soumission',
#   'Rating': 'One',
#   'Link': 'soumission_998/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'Sharp Objects',
#   'Rating': 'Four',
#   'Link': 'sharp-objects_997/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'Sapiens: A Brief History of Humankind',
#   'Rating': 'Five',
#   'Link': 'sapiens-a-brief-history-of-humankind_996/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'The Requiem Red',
#   'Rating': 'One',
#   'Link': 'the-requiem-red_995/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'The Dirty Little Secrets of Getting Your Dream Job',
#   'Rating': 'Four',
# ...

# %%
len(data)
# Out:
# 1000

# %% [markdown]
# ## Expresiones regulares

# %%
html = requests.get('http://books.toscrape.com/catalogue/category/books_1/page-2.html')
#print(page)
soup = BeautifulSoup(html.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Books |
#      Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="
#
# " name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../../../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# importamos la libreria de regular expresion
import re
item = soup.select_one('li.current')
# \d cualquier digito del 0 al 9 y el "+" es para que sean varios
# agrupaciones de 1 o más digitos
patron = r'Page (\d+) of (\d+)'
# match o concordar
match = re.search(patron, html.text)
#print(match)

if match:
    page_number = int(match.group(1))
    total_pages = int(match.group(2))
    print(page_number, total_pages)
# Out:
# 2 50

# %%
url_base = 'http://books.toscrape.com/catalogue/category/books_1'  # Reemplaza con tu URL base
num_paginas = total_pages  # Reemplaza con el número total de páginas

manejar_paginacion(url_base, num_paginas)

# %%
#html = requests.get('http)

# %%
import pandas as pd

# %%
# y sería al final hacer el Data Frame con toda la info
datos = pd.DataFrame(data)
datos
# Out:
#                                                  Título Rating  \
# 0                                  A Light in the Attic  Three
# 1                                    Tipping the Velvet    One
# 2                                            Soumission    One
# 3                                         Sharp Objects   Four
# 4                 Sapiens: A Brief History of Humankind   Five
# ...                                                 ...    ...
# 1995  Alice in Wonderland (Alice's Adventures in Won...    One
# 1996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)   Four
# 1997  A Spy's Devotion (The Regency Spies of London #1)   Five
# 1998                1st to Die (Women's Murder Club #1)    One
# 1999                 1,000 Places to See Before You Die   Five
#
#                                                    Link Existencia
# 0                  a-light-in-the-attic_1000/index.html   In stock
# 1                     tipping-the-velvet_999/index.html   In stock
# ...

# %% [markdown]
# ### Script

# %%
import requests
from bs4 import BeautifulSoup

# %%
def obtener_contenido_pagina(url):
    response = requests.get(url)
    return response.content

# %%
def analizar_contenido_html(html):
    return BeautifulSoup(html,'html.parser')

# %%
url = requests.get("https://www.cyberpuerta.mx/Promociones/")
soup = BeautifulSoup(url.content,"html.parser")

# %%
titulos = []
titulo_items = soup.find_all('div','emproduct_right')

for items in titulo_items:
    titulo = items.a.text.strip()
    titulos.append(titulo)

titulos
# Out:
# ['Procesador AMD Ryzen 5 3600, S-AM4, 3.60GHz, 32MB L3 Cache, con Disipador Wraith Stealth',
#  'Gabinete MSI MPG GUNGNIR 110R con Ventana ARGB, Midi-Tower, ATX/Micro-ATX/Mini-ITX, USB 3.0, sin Fuente, 4 Ventiladores ARGB Instalados, Blanco',
#  'Multifuncional Brother MFC-T920DW InkBenefit Tank, Color, Inyección, Inalámbrico, Print/Scan/Copy/Fax',
#  'SSD XPG SPECTRIX S20G, 1TB, PCI Express 3.0, M.2',
#  'Monitor Samsung LS19A330NHLXZX LED 19", Full HD, HDMI, Negro',
#  'Mouse Gamer Ocelot Gaming Óptico OGMM02, Alámbrico, USB A, 3200DPI, Negro',
#  'Mouse Gamer Ocelot Gaming Óptico OGMM01, Alámbrico, USB A, 6400DPI, Negro',
#  'Mouse Gamer Ocelot Gaming Óptico OGEM02, Alámbrico, USB A, 2400DPI, Negro',
#  'Mouse Gamer Ocelot Gaming Óptico OGMM03, Alámbrico, USB A, 3200DPI, Negro/Rosa',
#  'Mouse Gamer Ocelot Gaming Óptico OGEM01, Alámbrico, USB A, 2400DPI, Negro',
#  'Ocelot Gaming Audífonos Gamer OGMH01 Alámbrico, 2.2 Metros, 3.5mm/USB, Negro',
# ...

# %%
data = []

def procesar_pagina(soup):
    titulos = []
    precios_originales = []
    precios_descuentos = []
    precios_envio = []
    skus = []
    stocks = []

    titulo_items = soup.find_all('div','emproduct_right')

    for items in titulo_items:
        titulo = items.a.text.strip()
        titulos.append(titulo)

    precio_original_items = soup.find_all('span', class_="oldPrice")

    for item in precio_original_items:
        precio_original = item.text.strip()
        precios_originales.append(precio_original)

    precio_descuento_items  = soup.find_all('div', class_='emproduct_right_price')

    for item in precio_descuento_items:
        precio_descuento = item.label.text.strip()
        precios_descuentos.append(precio_descuento)

    sku_items  = soup.find_all('div', class_='emproduct_right_artnum')

    for item in sku_items:
        sku = item.text.strip()
        skus.append(sku.lstrip("SKU: "))

    precio_envio_items  = soup.find_all('span', class_={'deliveryvalue','deliverytextframe'})

    for item in precio_envio_items:
        precio_envio = item.text
        precios_envio.append(precio_envio)

    stock_items  = soup.find_all('div', class_='emstock')

    for item in stock_items:
        stock = item.text.strip()
        stocks.append(stock[1])

    min_length = min(len(titulos),len(skus),len(precios_originales),len(precios_descuentos),len(precios_envio),len(stocks))

    for i in range(min_length):
        data.append({
            "Título": titulos[i] if i<len(titulos) else None,
            "Sku": skus[i] if i<len(sku_items) else None,
            "Precio original": precios_originales[i]  if i<len(precios_originales) else None,
            "Precio Descuento": precios_descuentos[i]  if i<len(precios_descuentos) else None,
            "Precio Envío": precios_envio[i]  if i<len(precios_envio) else None,
            "Stock": stocks[i] if i<len(stocks) else None
        })

# %%
def manejar_paginacion(url_base, num_paginas):
    for i in range(2, num_paginas+1):
        url = url_base +  str(i) + "/"
        #print(url)
        contenido_pagina = obtener_contenido_pagina(url)
        soup = analizar_contenido_html(contenido_pagina)
        procesar_pagina(soup)

# %%
url_base = "https://www.cyberpuerta.mx/Promociones/"
num_paginas = 8

manejar_paginacion(url_base,num_paginas)

# %%
data
# Out:
# [{'Título': 'Mouse Gamer Ocelot Gaming Óptico White Pearl, Alámbrico, USB, 7200DPI, Blanco',
#   'Sku': 'OCM WHITE PEARL',
#   'Precio original': '$299.00',
#   'Precio Descuento': '$158.00',
#   'Precio Envío': '$99.00',
#   'Stock': 'i'},
#  {'Título': "Cinta Zebra Ribbon Resin 5095, 4.33'' x 110mm, 6 Piezas",
#   'Sku': '05095BK11045',
#   'Precio original': '$6,999.00',
#   'Precio Descuento': '$1,169.00',
#   'Precio Envío': '$99.00',
#   'Stock': 'i'},
#  {'Título': 'Ocelot Gaming Audífonos Gamer OGMH02, Alámbrico, 2.2 Metros, 3.5mm/USB, Negro',
#   'Sku': 'OGMH02',
#   'Precio original': '$387.00',
#   'Precio Descuento': '$215.00',
#   'Precio Envío': '$99.00',
#   'Stock': 'i'},
#  {'Título': 'Router ASUS Gigabit Ethernet de Banda Dual RT-AC66U B1 AC1750 para Gaming con AiMesh, Inalámbrico, 1300 Mbit/s, 4x RJ-45, 2.4/5GHz, 3 Antenas',
#   'Sku': '90IG0300-BA1000',
#   'Precio original': '$1,915.00',
#   'Precio Descuento': '$1,099.00',
#   'Precio Envío': '$99.00',
# ...

# %%
len(data)
# Out:
# 110

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                 Título               Sku  \
# 0    Mouse Gamer Ocelot Gaming Óptico White Pearl, ...   OCM WHITE PEARL
# 1    Cinta Zebra Ribbon Resin 5095, 4.33'' x 110mm,...      05095BK11045
# 2    Ocelot Gaming Audífonos Gamer OGMH02, Alámbric...            OGMH02
# 3    Router ASUS Gigabit Ethernet de Banda Dual RT-...   90IG0300-BA1000
# 4      Panduit Módulo Ciego Gris, Paquete de 10 Piezas           CMBIG-X
# ..                                                 ...               ...
# 105                 SSD HP S650, 960GB, SATA III, 2.5"           345N0AA
# 106  Procesador AMD Ryzen 9 5950X, S-AM4, 3.40GHz, ...  100-100000059WOF
# 107  Vorago Silla Gamer CGC500, hasta 120kg, Negro/...        CGC-500/BL
# 108  Tarjeta Madre MSI Micro ATX A320M-A PRO, S-AM4...       A320M-A PRO
# 109  Astro Gaming Audífonos Gamer A10 para PS4/PS5/...        939-001594
#
#     Precio original Precio Descuento Precio Envío Stock
# ...

# %%
import datetime
fecha_actual = datetime.datetime.now().strftime("%d-%m-%Y")
df.to_csv(f"..
